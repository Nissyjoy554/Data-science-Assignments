# %% [markdown]
# # ASSOCIATION RULES

# %%
data=pd.read_excel("C:\\Users\\Admin\\AppData\\Local\\Temp\\Rar$DIa0.393\\Online retail.xlsx")

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

transactions = data['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil'].apply(lambda x: x.split(','))

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False    False              False      False    False        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False     True        False
# 3       False    False              False      False    False        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False           False
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...    True           False
# 3  False           False      False        False  ...   False           False
# 4  False           False      False        False  ...   False           False
#
# ...

# %%
df.isnull().sum()
# Out:
#  asparagus           0
# almonds              0
# antioxydant juice    0
# asparagus            0
# avocado              0
#                     ..
# whole wheat pasta    0
# whole wheat rice     0
# yams                 0
# yogurt cake          0
# zucchini             0
# Length: 120, dtype: int64

# %%
df.drop_duplicates()
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False    False              False      False    False        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False     True        False
# 3          False    False              False      False    False        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7492       False    False              False      False    False        False
# 7493       False    False              False      False    False        False
# 7495       False    False              False      False    False        False
# 7496       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
#
# ...

# %%
# Apply Apriori
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                               itemsets
# 0    0.029303                              (almonds)
# 1    0.011062                    (antioxydant juice)
# 2    0.045993                              (avocado)
# 3    0.012614                                (bacon)
# 4    0.015525                       (barbecue sauce)
# ..        ...                                    ...
# 431  0.014749  (mineral water, olive oil, spaghetti)
# 432  0.016689   (mineral water, pancakes, spaghetti)
# 433  0.012420     (mineral water, shrimp, spaghetti)
# 434  0.010867       (mineral water, spaghetti, soup)
# 435  0.013584   (mineral water, tomatoes, spaghetti)
#
# [436 rows x 2 columns]

# %%
# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.2)
rules
# Out:
#                     antecedents                 consequents  \
# 0               (mineral water)                   (almonds)
# 1                     (almonds)             (mineral water)
# 2                     (avocado)                 (chocolate)
# 3                   (chocolate)                   (avocado)
# 4                     (avocado)              (french fries)
# ..                          ...                         ...
# 953  (mineral water, spaghetti)                  (tomatoes)
# 954       (tomatoes, spaghetti)             (mineral water)
# 955             (mineral water)       (tomatoes, spaghetti)
# 956                  (tomatoes)  (mineral water, spaghetti)
# 957                 (spaghetti)   (mineral water, tomatoes)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.299825            0.029303  0.010867    0.036246  1.236923
# 1              0.029303            0.299825  0.010867    0.370861  1.236923
# ...

# %%
rules_sorted=rules.sort_values(by='lift',ascending=False)
rules_sorted
# Out:
#                antecedents            consequents  antecedent support  \
# 524            (olive oil)    (whole wheat pasta)            0.087910
# 525    (whole wheat pasta)            (olive oil)            0.040753
# 910  (mineral water, milk)                 (soup)            0.067922
# 915                 (soup)  (mineral water, milk)            0.071221
# 396        (herb & pepper)          (ground beef)            0.066757
# ..                     ...                    ...                 ...
# 374            (green tea)       (low fat yogurt)            0.168834
# 95             (champagne)        (mineral water)            0.054725
# 94         (mineral water)            (champagne)            0.299825
# 174        (mineral water)              (cookies)            0.299825
# 175              (cookies)        (mineral water)            0.060353
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# ...

# %% [markdown]
# # INTERVIEW QUESTIONS:

# %% [markdown]
# # 1.	What is lift and why is it important in Association rules?

# %%
Lift is a measure used in association rule mining to evaluate the strength of an association between two items or itemsets. In simple terms, it helps to identify how much more likely it is for two items to be found together than would be expected by chance.

IMPORTANCE:
   Lift is important in association rules because it shows how much more likely two items are to occur together than by random
chance. A higher lift value indicates a stronger and more significant association between the items, helping to identify
meaningful patterns in the data.

# %% [markdown]
# # 2.	What is support and Confidence. How do you calculate them?

# %%
SUPPORT:
    Support is a number of transactions in which antecedent and consequent appear in the data
CALCULATION:
    Transaction with antecedent and consequent / Total Transactions
CONFIDENCE:
    Confidence is a number of antecedent transactions that also have the consequent item set
CALCULATION:
    Transactions with antecedent and consequent /Transaction with antecedent

# %% [markdown]
# # 3.	What are some limitations or challenges of Association rules mining?

# %%
1.Too Many Rules: You might get lots of rules, many of which could be trivial or redundant.

2.Interpreting Rules: It can be hard to understand which rules are useful or meaningful.

3.Binary Data: The technique usually doesn’t consider how much or how often items are bought.

5.Data Quality: Poor data quality can lead to misleading results.
